# %%
import torch

input_ids = torch.tensor([[1, 2, 3, 4, 5]])
targets = torch.zeros_like(input_ids)

targets[:, :-1] = input_ids[:, 1:]
targets[:, -1] = -1

print(input_ids)
print(targets)
# Out:
# tensor([[1, 2, 3, 4, 5]])
# tensor([[ 2,  3,  4,  5, -1]])
